# %%
from providers.mangadex import MangaDex
from PIL import display

# %%
MangaDex.search_manga("Mercenary Enrol")
# Out:
# ['9ecd208c-c592-4462-9f57-4d7d4a9f956f']

# %%
max_level_player = MangaDex("9ecd208c-c592-4462-9f57-4d7d4a9f956f")
max_level_player = max_level_player.get_metadata()

# %%
max_level_player
# Out:
# {'provider': 'MangaDex', 'id_token': '9ecd208c-c592-4462-9f57-4d7d4a9f956f', 'titles': ['Mercenary Enrollment', 'Teenage Mercenary'], 'tags': ['Action', 'Long Strip', 'Crime', 'Adventure', 'Military', 'Drama', 'School Life', 'Delinquents', 'Web Comic', 'Full Color'], 'summary': 'Yu Ijin was the sole survivor of a plane crash when he was little. After becoming a mercenary to survive for 10 years, he returns to his family in his hometown.\n\n---\nAt the age of eight, Ijin Yu lost his parents in a plane crash and became stranded in a foreign land, forced to become a child mercenary in order to stay alive. He returns home ten years later to be reunited with his family in Korea, where food and shelter are plenty and everything seems peaceful. But Ijin will soon learn that life as a teenager is a whole other feat of survival. With only one year of high school left, Ijin must master new tactics to maneuver his way around the schoolhouse battleground. Can he survive a year of high school? Or
# ...

# %%
display(max_level_player.cover_art)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x623>
